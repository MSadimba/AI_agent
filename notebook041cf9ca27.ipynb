# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")
# Out:
# ✅ ADK components imported successfully.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""", # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > Here's a blog outline about the benefits of multi-agent systems for software developers:
#
# ## **Headline:** Unleash Your Software's Superpowers: Why Multi-Agent Systems are Your Next Big Thing
#
# ### **Introduction Hook:**
# Tired of monolithic codebases and complex interdependencies slowing down your development? Imagine software that can intelligently collaborate, adapt, and solve problems with the power of multiple specialized "brains." This isn't science fiction – it's the reality of multi-agent systems (MAS), and they're poised to revolutionize how we build software.
#
# ---
#
# ### **Main Section 1: Enhanced Problem Solving Through Specialization**
#
# *   **Divide and Conquer, Smarter:** MAS allow you to break down complex problems into smaller, manageable tasks, each handled by an agent with specialized skills. This leads to more efficient and robust solutions.
# *   **Intelligent Delegation:** Agents can negotiate and delegate tasks amongst themselves based on their capabilities and current workload, optimizing resource utilization and task completion.
# *   **Emergent Behavior for Novel Solutions:** The interaction of simple agents can lead to complex, emergent behaviors that solve problems in ways a single, monolithic system might not even consider.
#
# ---
#
# ### **Main Section 2: Increased Robustness and Resilience**
#
# *   **Fault Tolerance is Built-In:** If one agent fails, the system can often continue operating by reassigning its tasks to other available agents, significantly improving its resilience to failures.
# *   **Adaptability to Dynamic Environments:** MAS can dynamically adjust their behavior and resource allocation in response to changing external conditions or internal states, making them ideal for unpredictable environments.
# *   **Decentralized Control for Stability:** Unlike centralized systems, the lack of a single point of control makes MAS less susceptible to catastrophic failures.
#
# ---
#
# ### **Main Section 3: Improved Scalability and Modularity**
#
# *   **Effortless Scaling:** Adding new capabilities or handling increased load is as simple as introducing more specialized agents into the system.
# *   **Modular Design for Maintainability:** Each agent can be developed, tested, and maintained independently, leading to cleaner codebases and faster development cycles.
# *   **Reusability of Agent Components:** Once developed, agents can be reused across different MAS projects, saving significant development time and effort.
#
# ---
#
# ### **Main Section 4: Fostering Innovation and Exploration**
#
# *   **Simulating Complex Scenarios:** MAS are powerful tools for simulating real-world complex systems, allowing for rigorous testing and exploration of different strategies.
# *   **Enabling Advanced AI Capabilities:** From sophisticated negotiation to learning and reasoning, MAS provide a framework for building more intelligent and autonomous software.
# *   **Pushing the Boundaries of Software Design:** Embracing MAS encourages a shift towards more distributed, collaborative, and intelligent software architectures.
#
# ---
#
# ### **Concluding Thought:**
# Multi-agent systems offer a powerful paradigm shift for software developers, moving beyond traditional approaches to unlock new levels of problem-solving, resilience, and scalability. By embracing this collaborative and intelligent architecture, you can build software that is not only more robust and adaptable but also opens doors to exciting new possibilities in the world of artificial intelligence and beyond. It's time to give your software superpowers.
# WriterAgent > ## Unleash Your Software's Superpowers: Why Multi-Agent Systems are Your Next Big Thing
#
# Are you tired of wrestling with monolithic codebases, where a change in one area sends ripples of unexpected bugs throughout your system? Imagine software that can intelligently collaborate, adapt, and solve problems with the power of multiple specialized "brains." This isn't science fiction – it's the reality of multi-agent systems (MAS), and they're poised to revolutionize how we build software.
#
# MAS enable a powerful "divide and conquer" approach. Complex problems are broken down into smaller, manageable tasks, each handled by an agent with specialized skills. This leads to more efficient and robust solutions. Agents can even intelligently delegate tasks among themselves, optimizing resource usage and ensuring completion. The beauty of MAS is that the interaction of these simple agents can lead to emergent behaviors, solving problems in ways a single, monolithic system might never consider.
#
# Beyond problem-solving, MAS bring enhanced robustness and resilience. If one agent encounters an issue, others can seamlessly take over its tasks, minimizing downtime. This adaptability makes MAS ideal for dynamic environments where conditions constantly shift. The decentralized nature of MAS also means there's no single point of failure, making your software far more stable.
#
# Furthermore, MAS offer improved scalability and modularity. Need to handle more load? Simply introduce more agents. Each agent can be developed, tested, and maintained independently, leading to cleaner code and faster development cycles. Plus, agents can be reused across projects, saving significant time and effort. Embracing MAS is a step towards more intelligent, collaborative, and powerful software. It's time to give your software superpowers!
# EditorAgent > ## Unleash Your Software's Superpowers: Why Multi-Agent Systems are Your Next Big Thing
#
# Are you tired of wrestling with monolithic codebases, where a change in one area sends ripples of unexpected bugs throughout your system? Imagine software that can intelligently collaborate, adapt, and solve problems with the power of multiple specialized "brains." This isn't science fiction – it's the reality of **Multi-Agent Systems (MAS)**, and they're poised to revolutionize how we build software.
#
# ### Enhanced Problem Solving Through Specialization
#
# MAS enable a powerful "divide and conquer" approach. Complex problems are broken down into smaller, manageable tasks, each handled by an agent with specialized skills. This leads to more efficient and robust solutions. Agents can even intelligently delegate tasks amongst themselves, optimizing resource usage and ensuring completion. The beauty of MAS lies in the **emergent behaviors** that arise from the interaction of these simple agents, allowing them to solve problems in ways a single, monolithic system might never consider.
#
# ### Increased Robustness and Resilience
#
# Beyond problem-solving, MAS bring enhanced robustness and resilience. If one agent encounters an issue, others can seamlessly take over its tasks, minimizing downtime. This inherent **fault tolerance** makes MAS ideal for dynamic environments where conditions constantly shift. The decentralized nature of MAS also means there's no single point of failure, making your software significantly more stable and less susceptible to catastrophic errors.
#
# ### Improved Scalability and Modularity
#
# Furthermore, MAS offer improved scalability and modularity. Need to handle more load? Simply introduce more specialized agents into the system. Each agent can be developed, tested, and maintained independently, leading to cleaner codebases and faster development cycles. This **modularity** also means agents can be reused across different projects, saving significant time and effort.
#
# ### Fostering Innovation and Exploration
#
# MAS are not just about fixing existing problems; they are also about unlocking new possibilities. They serve as powerful tools for **simulating complex scenarios**, allowing for rigorous testing and exploration of different strategies. MAS provide a framework for building more intelligent and autonomous software, pushing the boundaries of what's possible in software design.
#
# Embracing MAS is a step towards more intelligent, collaborative, and powerful software. It's time to give your software superpowers!

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > **Health:** Gene therapy is showing remarkable promise, with recent successes in treating inherited hearing loss and sickle cell anemia. Within 5-10 years, expect wider applications for genetic disorders and potentially even cancer treatments. Additionally, CAR T-cell therapy is evolving, offering new hope for brain cancers, with ongoing research aiming to refine its application. A significant development for preventative health is the emergence of innovative allergy medications and long-acting HIV prevention injections, with broader accessibility anticipated within 3-5 years.
#
# **Technology:** Artificial intelligence continues its rapid integration, with "agentic AI" enabling autonomous workflows and virtual coworkers. Practical applications for AI in areas like diagnostics and personalized medicine are expected to expand significantly within 2-5 years. Furthermore, advances in 3D printing are pushing towards printing complex tissues and organs, a development that could revolutionize transplantation within the next decade.
#
# **Finance:** Blockchain technology is streamlining financial processes, enhancing transparency and reducing costs in areas like bond issuance and lending, with wider adoption expected in 3-5 years. AI and machine learning are also transforming risk assessment and customer experience within the financial sector, with advanced applications becoming more common in the next 2-4 years.
# TechResearcher > **AI and Machine Learning Trends Shaping 2025**
#
# **Key Developments:**
#
# 1.  **Agentic AI & Generative AI:** AI systems are becoming increasingly autonomous, capable of planning and executing complex tasks. Generative AI continues to dominate, expanding beyond text to create sophisticated multimedia content like images, video, and music. Companies like **Google** (Gemini), **OpenAI**, and **Microsoft** are leading this wave.
# 2.  **AI in Cybersecurity & Responsible AI:** The dual role of AI in enhancing cybersecurity defenses while also posing new threats is a major trend. Simultaneously, there's a growing emphasis on **AI governance platforms** and **explainable AI (XAI)** to ensure ethical, transparent, and secure AI deployments. Major tech players like **Google**, **Microsoft**, and **NVIDIA** are developing solutions in this space.
# 3.  **AI-Powered Healthcare & Finance:** AI is revolutionizing diagnostics and personalized treatments in healthcare, enabling faster and more accurate disease detection. In finance, AI is used for market trend analysis, fraud detection, and enhanced customer service via chatbots, though concerns about data privacy and job displacement persist. Companies like **Google** and **NVIDIA** are key players in both sectors.
#
# **Main Companies Involved:**
#
# *   **Tech Giants:** Google, Microsoft, NVIDIA, Amazon, IBM, Meta.
# *   **AI Research & Development:** OpenAI, Anthropic, Mistral AI.
# *   **Data & Platform Providers:** Databricks, Cloudera.
#
# **Potential Impact:**
#
# These trends promise significant advancements in automation, efficiency, and personalized services across industries. However, they also raise critical concerns regarding data privacy, ethical deployment, potential job displacement, and the need for robust AI governance. The integration of AI is poised to reshape business operations, economic landscapes, and societal norms.
# FinanceResearcher > Here's a daily briefing covering Tech, Health, and Finance:
#
# **Tech:** Intel's CEO is now overseeing AI efforts following a CTO departure to OpenAI. Meanwhile, AI infrastructure remains a hot area, with Microsoft securing a significant cloud deal with an Australian firm and Cisco seeing AI networking momentum. The global race for AI compute capacity continues.
#
# **Health:** A Nebraska report indicates good overall health but highlights disparities linked to employment and income. Globally, the Africa CDC is holding a briefing on health emergencies, while in Chicago, mpox vaccination events are ongoing. In health policy, ACA subsidies are still in limbo as a government shutdown resolution is sought, and discussions around healthcare costs persist.
#
# **Finance:** Financial reporting priorities are a key focus, with leaders from the SEC, PCAOB, and FASB set to speak at the CFRI 2025 Conference. Rigetti Computing announced its Q3 2025 financial results and provided updates on its quantum computing roadmap. Macroeconomic schedules include key data releases from Japan, the UK, and Germany for November 11, 2025.
#
# ---
#
# **Fintech Trends Report:**
#
# **1. Embedded Finance:**
# *   **Market Implication:** Non-financial companies are increasingly integrating financial services (payments, lending, insurance) directly into their customer experiences. This drives customer loyalty and creates new revenue streams.
# *   **Future Outlook:** Expect deeper integration across more industries, with a focus on personalization and seamless user journeys.
#
# **2. AI and Machine Learning:**
# *   **Market Implication:** AI/ML is revolutionizing fraud detection, credit scoring, personalized financial advice (robo-advisors), and algorithmic trading. This leads to greater efficiency and more accurate decision-making.
# *   **Future Outlook:** Advancements in AI will enable more sophisticated predictive analytics and hyper-personalized financial products, potentially leading to greater financial inclusion.
#
# **3. Decentralized Finance (DeFi):**
# *   **Market Implication:** DeFi offers alternative financial systems built on blockchain, enabling peer-to-peer transactions without traditional intermediaries. This can lead to lower costs and greater accessibility.
# *   **Future Outlook:** While facing regulatory hurdles, DeFi's potential for innovation in lending, trading, and asset management will continue to drive its development, potentially challenging traditional finance.
# AggregatorAgent > ## Executive Summary: Tech, Health, and Finance Briefing
#
# **Key Takeaways:**
#
# Artificial Intelligence (AI) remains the central driving force across all three sectors, promising transformative advancements and raising critical governance concerns. In **Technology**, AI is rapidly evolving towards more autonomous "agentic" systems and sophisticated generative capabilities, while the demand for AI compute power continues to surge. This tech boom is intrinsically linked to **Finance**, where AI is revolutionizing fraud detection, risk assessment, and customer experience, alongside the growing influence of embedded finance and Decentralized Finance (DeFi) built on blockchain.
#
# In **Health**, AI is a key enabler of personalized medicine, revolutionizing diagnostics and treatment plans, while gene therapy and CAR T-cell treatments offer groundbreaking solutions for genetic disorders and cancers. Preventative health is also seeing innovation with new allergy medications and long-acting HIV prevention.
#
# **Surprising Connections & Overarching Themes:**
#
# The most striking connection is the pervasive influence of AI, acting as a dual-edged sword: an engine for innovation in health and finance, yet also demanding responsible governance and ethical considerations. Furthermore, the drive for **personalization** is evident across all sectors, from personalized medical treatments to hyper-personalized financial products and AI-driven customer experiences. The increasing integration of previously siloed services, like embedded finance, highlights a trend towards seamless user journeys.
#
# **Most Important Trends:**
#
# 1.  **Pervasive AI Integration:** AI's expanding capabilities in autonomy, generation, and predictive analytics are reshaping industries, demanding robust governance and ethical frameworks.
# 2.  **Personalization Revolution:** From tailored healthcare to individualized financial advice, personalized solutions are becoming the norm.
# 3.  **Transformative Health Innovations:** Gene therapy, CAR T-cell treatments, and advanced preventative medicines are set to redefine healthcare outcomes.
# 4.  **Financial Disruption:** Embedded finance and DeFi are challenging traditional financial models, while AI drives efficiency and new revenue streams.

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the great lens, the salt spray a constant companion. For thirty years, the beam had been his world. Tonight, however, a strange shimmer caught his eye, not from the sea, but from a tattered chart tucked behind a stack of old logbooks. It was a map he’d never seen, depicting a cluster of islands far to the north. As his lamp’s glow fell upon it, the lines and symbols on the parchment began to pulse with an ethereal blue light. A single, blinking star appeared, then faded, then reappeared, seemingly pointing towards the very horizon Elias watched over. His heart, usually as steady as the tide, began to race.
# CriticAgent > Here's a review of the provided story:
#
# **Plot:** The plot effectively establishes a sense of mystery and intrigue. The discovery of the glowing map is a strong inciting incident that immediately hooks the reader and promises adventure. The map’s pulsing light and blinking star create a sense of the supernatural or otherworldly, which elevates the stakes beyond a simple cartographical find.
#
# **Characters:** Elias is presented as a dedicated and solitary figure, defined by his routine and his long tenure as a lighthouse keeper. His reaction – a racing heart against his usual steady demeanor – is a good indicator of the profound impact the discovery has on him. However, he is currently a bit of a blank slate beyond his profession.
#
# **Pacing:** The pacing is excellent for a short snippet. It moves quickly from establishing Elias's life to the moment of discovery, building suspense efficiently. The description of the map's reaction to the light is detailed enough to be captivating without slowing the narrative down.
#
# Here are 2-3 specific, actionable suggestions for improvement:
#
# 1.  **Flesh out Elias's inner world:** While his racing heart is a good start, consider adding a brief internal thought or question Elias might have that hints at his past desires or a dormant sense of adventure. For instance, does he ever wonder what lies beyond his horizon? A sentence or two of this internal reflection would make his connection to the map's mystery more personal.
# 2.  **Hint at the map's origin or nature:** The map is described as "tattered" and "old," which is good, but the "ethereal blue light" and blinking star suggest something more than just a conventional chart. Briefly hinting at the source of this luminescence or its potential purpose (e.g., "a relic from a forgotten age" or "a guide to the impossible") would deepen the intrigue.
# 3.  **Introduce a sensory detail beyond sight:** The story focuses heavily on the visual aspect of the map. Consider adding another sensory detail to enhance the experience of discovery. Does the map emit a faint hum, a strange warmth, or a scent distinct from the sea salt and old paper?
# RefinerAgent > Elias polished the great lens, the salt spray a constant companion. For thirty years, the beam had been his world. But in the quiet hum of the lantern room, a question had always whispered at the edges of his mind: what lay beyond the endless horizon? Tonight, however, a strange shimmer caught his eye, not from the sea, but from a tattered chart tucked behind a stack of old logbooks. It was a map he’d never seen, depicting a cluster of islands far to the north. As his lamp’s glow fell upon it, the lines and symbols on the parchment began to pulse with an ethereal blue light, accompanied by a faint, resonant hum that seemed to vibrate in his very bones. A single, blinking star appeared, then faded, then reappeared, seemingly pointing towards the very horizon Elias watched over. A relic from a forgotten age, perhaps, or a guide to the impossible. His heart, usually as steady as the tide, began to race, no longer just with surprise, but with a burgeoning sense of long-dormant adventure.
# CriticAgent > Your refinements have significantly improved the story. The addition of Elias's internal question about the horizon and the description of the map's hum vibrating in his bones are excellent. The phrase "A relic from a forgotten age, perhaps, or a guide to the impossible" is a perfect hook that deepens the mystery and hints at the map's potential significance. The concluding sentence effectively captures Elias's emotional shift.
#
# APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
